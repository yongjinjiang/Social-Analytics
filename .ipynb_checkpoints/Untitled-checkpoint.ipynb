# %%
# Dependencies
import tweepy
import pandas as pd
import json
import sys
sys.path.append("../")
import numpy as np
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term

target_names = ["@BBC","@CBS","@CNN","@FoxNews","@nytimes"]
# Grab 25 tweets
#public_tweets = api.search(target_term, count=25, result_type="recent")
tweet_df=pd.DataFrame(columns=target_names)
for name in target_names:
     compound_list
     public_tweets = api.user_timeline(screen_name=name,count=100,tweet_mode='extended')
        for tweet in public_tweets:
        # Run Vader Analysis on each tweet
            result= analyzer.polarity_scores(tweet["text"])
            compound=result["compound"]
            pos = result["pos"]
            neu = result["peu"]
            neg = result["pos"]

    # Add each value to the appropriate array
    compound_list.append(compound)
    positive_list.append(pos)
    negative_list.append(neg)
    neutral_list.append(neu)
#for tweet in public_tweets["statuses"]:
 #   print(tweet["text"])
for i in range(99):
    public_tweets[i]['created_at']

# %%
tweet;

# %%
;
# Out:
# ''

# %%
analyzer.polarity_scores(public_tweets[0]['full_text'])
# Out:
# {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.3182}

# %%
public_tweets[0];

# %%
import pandas as pd
target_names = ["@BBC","@CBS","@CNN","@FoxNews","@nytimes"]
num_list=[str(i)*4 for i in range(100)]
sentiment_elements=["neg",'neu','pos','compound']

#https://pandas.pydata.org/pandas-docs/stable/advanced.html
tuples=[]
tuples=[]
for i in range(100):
    arrays=[[str(i)]*4,sentiment_elements]
    for j in range(4):
        tuples.append(list(zip(*arrays))[j])
    
index=pd.MultiIndex.from_tuples(tuples,names=['#', 'sentiment']);
tweet_df=pd.DataFrame(columns=target_names,index=index)
# Out:
#   File "<ipython-input-54-824424b45263>", line 11
#     index=pd.MultiIndex.from_tuples(tuples,names=['#', 'sentiment']);
#         ^
# SyntaxError: invalid syntax

# %%
#https://pandas.pydata.org/pandas-docs/stable/advanced.html
tuples=[]
for i in range(100):
    arrays=[[str(i)]*4,sentiment_elements]
    for j in range(4):
        tuples.append(list(zip(*arrays))[j])
    
index=pd.MultiIndex.from_tuples(tuples,names=['#', 'sentiment']);
tweet_df=pd.DataFrame(columns=target_names,index=index)

# %%
tweet_df
# Out:
#              @BBC @CBS @CNN @FoxNews @nytimes
# #  sentiment
# 0  neg        NaN  NaN  NaN      NaN      NaN
#    neu        NaN  NaN  NaN      NaN      NaN
#    pos        NaN  NaN  NaN      NaN      NaN
#    compound   NaN  NaN  NaN      NaN      NaN
# 1  neg        NaN  NaN  NaN      NaN      NaN
#    neu        NaN  NaN  NaN      NaN      NaN
#    pos        NaN  NaN  NaN      NaN      NaN
#    compound   NaN  NaN  NaN      NaN      NaN
# 2  neg        NaN  NaN  NaN      NaN      NaN
#    neu        NaN  NaN  NaN      NaN      NaN
#    pos        NaN  NaN  NaN      NaN      NaN
#    compound   NaN  NaN  NaN      NaN      NaN
# 3  neg        NaN  NaN  NaN      NaN      NaN
#    neu        NaN  NaN  NaN      NaN      NaN
#    pos        NaN  NaN  NaN      NaN      NaN
#    compound   NaN  NaN  NaN      NaN      NaN
# 4  neg        NaN  NaN  NaN      NaN      NaN
#    neu        NaN  NaN  NaN      NaN      NaN
#    pos        NaN  NaN  NaN      NaN      NaN
# ...

# %%
tuples
# Out:
# [(1, 'neg'), (1, 'neu'), (1, 'pos'), (1, 'compound')]

# %%
arrays
# Out:
# [['99', '99', '99', '99'], ['neg', 'neu', 'pos', 'compound']]

# %%
tuples
# Out:
# [('0', 'neg'),
#  ('0', 'neu'),
#  ('0', 'pos'),
#  ('0', 'compound'),
#  ('1', 'neg'),
#  ('1', 'neu'),
#  ('1', 'pos'),
#  ('1', 'compound'),
#  ('2', 'neg'),
#  ('2', 'neu'),
#  ('2', 'pos'),
#  ('2', 'compound'),
#  ('3', 'neg'),
#  ('3', 'neu'),
#  ('3', 'pos'),
#  ('3', 'compound'),
#  ('4', 'neg'),
#  ('4', 'neu'),
#  ('4', 'pos'),
#  ('4', 'compound'),
#  ('5', 'neg'),
#  ('5', 'neu'),
#  ('5', 'pos'),
#  ('5', 'compound'),
#  ('6', 'neg'),
#  ('6', 'neu'),
#  ('6', 'pos'),
#  ('6', 'compound'),
#  ('7', 'neg'),
#  ('7', 'neu'),
#  ('7', 'pos'),
#  ('7', 'compound'),
#  ('8', 'neg'),
#  ('8', 'neu'),
#  ('8', 'pos'),
#  ('8', 'compound'),
#  ('9', 'neg'),
#  ('9', 'neu'),
#  ('9', 'pos'),
#  ('9', 'compound'),
#  ('10', 'neg'),
#  ('10', 'neu'),
#  ('10', 'pos'),
#  ('10', 'compound'),
#  ('11', 'neg'),
#  ('11', 'neu'),
#  ('11', 'pos'),
#  ('11', 'compound'),
#  ('12', 'neg'),
#  ('12', 'neu'),
#  ('12', 'pos'),
#  ('12', 'compound'),
#  ('13', 'neg'),
#  ('13', 'neu'),
# ...
