# %%
# Dependencies
import tweepy
import os
import pandas as pd
import time
import spacy
import en_core_web_sm
import matplotlib
import json
import numpy as np
import sys
sys.path.append("/Users/jyj/Dropbox/A_A_Data_Analysis/Group_Projects")
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
target_term="@realDonaldTrump"
#mentions = api.home_timeline(count=5)
mentions  = api.search(q=target_term,result_type='mixed')
mentions
for tweet in tweepy.Cursor(api.search,
                           q=target_term,
                           count=100,
                           result_type="recent",
                           include_entities=True,
                           lang="en").items():
    print(tweet)
# Out:
# {'statuses': [{'created_at': 'Sun Dec 09 16:10:47 +0000 2018',
#    'id': 1071799326630862848,
#    'id_str': '1071799326630862848',
#    'text': "It's #SundayMorning and we haven't asked this question in awhile, but I think now is an appropriate time to do so:… https://t.co/P8U494oqNt",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'SundayMorning', 'indices': [5, 19]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/P8U494oqNt',
#       'expanded_url': 'https://twitter.com/i/web/status/1071799326630862848',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 21059255,
#     'id_str': '21059255',
#     'name': 'Ted Lieu',
#     'screen_name': 'tedlieu',
#     'location': 'California',
#     'description': "Husband of Betty, the love of my life. Father of two great kids. USAF veteran. Member of Congress. In that order. Also, I don't take orders from Vladimir Putin.",
#     'url': 'https://t.co/YZX138uDSy',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/YZX138uDSy',
#         'expanded_url': 'http://www.TedLieu.com',
#         'display_url': 'TedLieu.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 878746,
#     'friends_count': 8491,
#     'listed_count': 5654,
#     'created_at': 'Tue Feb 17 03:12:31 +0000 2009',
#     'favourites_count': 33231,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 19708,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/537271043937673217/3O1qePzP_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/537271043937673217/3O1qePzP_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21059255/1485531357',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1071474783978700800,
#    'quoted_status_id_str': '1071474783978700800',
#    'quoted_status': {'created_at': 'Sat Dec 08 18:41:10 +0000 2018',
#     'id': 1071474783978700800,
#     'id_str': '1071474783978700800',
#     'text': 'This is INSANE. --&gt; After Khashoggi\'s murder, "Mr. Kushner has offered the crown prince advice about how to weather… https://t.co/Cjgi9FkZhJ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Cjgi9FkZhJ',
#        'expanded_url': 'https://twitter.com/i/web/status/1071474783978700800',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [120, 143]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 16684243,
#      'id_str': '16684243',
#      'name': 'Karen Attiah',
#      'screen_name': 'KarenAttiah',
#      'location': 'Washington D.C.',
#      'description': "Global Opinions editor, @WashingtonPost | Stuntwoman for WaPo's award-winning TL;DR series | #JamalKhashoggi |karen.attiah@washpost.com",
#      'url': 'https://t.co/7BsyGzezsC',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/7BsyGzezsC',
#          'expanded_url': 'http://washingtonpost.com/people/karen-attiah',
#          'display_url': 'washingtonpost.com/people/karen-a…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 127214,
#      'friends_count': 6761,
#      'listed_count': 1510,
#      'created_at': 'Fri Oct 10 15:12:54 +0000 2008',
#      'favourites_count': 35950,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 57141,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'D186C8',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/960883105795137537/Cm5mSYgd_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/960883105795137537/Cm5mSYgd_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16684243/1435898226',
#      'profile_link_color': '086BFF',
#      'profile_sidebar_border_color': '00F7FF',
#      'profile_sidebar_fill_color': 'BD99AF',
#      'profile_text_color': '182C4A',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6975,
#     'favorite_count': 11355,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 9364,
#    'favorite_count': 27950,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Dec 09 17:52:04 +0000 2018',
#    'id': 1071824817324646400,
#    'id_str': '1071824817324646400',
#    'text': 'After House Republicans got crushed in the midterms, they came up with the brilliant idea of interviewing James Com… https://t.co/Nl1NVHrKCh',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Nl1NVHrKCh',
#       'expanded_url': 'https://twitter.com/i/web/status/1071824817324646400',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 21059255,
#     'id_str': '21059255',
#     'name': 'Ted Lieu',
#     'screen_name': 'tedlieu',
#     'location': 'California',
#     'description': "Husband of Betty, the love of my life. Father of two great kids. USAF veteran. Member of Congress. In that order. Also, I don't take orders from Vladimir Putin.",
#     'url': 'https://t.co/YZX138uDSy',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/YZX138uDSy',
#         'expanded_url': 'http://www.TedLieu.com',
#         'display_url': 'TedLieu.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 878746,
#     'friends_count': 8491,
#     'listed_count': 5654,
#     'created_at': 'Tue Feb 17 03:12:31 +0000 2009',
#     'favourites_count': 33231,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 19708,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/537271043937673217/3O1qePzP_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/537271043937673217/3O1qePzP_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21059255/1485531357',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'A8C7F7',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1071764777679114240,
#    'quoted_status_id_str': '1071764777679114240',
#    'quoted_status': {'created_at': 'Sun Dec 09 13:53:30 +0000 2018',
#     'id': 1071764777679114240,
#     'id_str': '1071764777679114240',
#     'text': 'Leakin’ James Comey must have set a record for who lied the most to Congress in one day. His Friday testimony was s… https://t.co/3wPMGjCLdw',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/3wPMGjCLdw',
#        'expanded_url': 'https://twitter.com/i/web/status/1071764777679114240',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 25073877,
#      'id_str': '25073877',
#      'name': 'Donald J. Trump',
#      'screen_name': 'realDonaldTrump',
#      'location': 'Washington, DC',
#      'description': '45th President of the United States of America🇺🇸',
#      'url': 'https://t.co/OMxB0x7xC5',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#          'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#          'display_url': 'Instagram.com/realDonaldTrump',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 56162746,
#      'friends_count': 46,
#      'listed_count': 97369,
#      'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#      'favourites_count': 8,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 39905,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': '6D5C18',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1543104015',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'BDDCAD',
#      'profile_sidebar_fill_color': 'C5CEC0',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': True,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 29117,
#     'favorite_count': 109731,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 3255,
#    'favorite_count': 11832,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 00:28:18 +0000 2018',
#    'id': 1071924531995000833,
#    'id_str': '1071924531995000833',
#    'text': 'It was never about Russia. The targeting of President @realDonaldTrump serves to protect Hillary Clinton and her en… https://t.co/vGurzEkgmv',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [54, 70]}],
#     'urls': [{'url': 'https://t.co/vGurzEkgmv',
#       'expanded_url': 'https://twitter.com/i/web/status/1071924531995000833',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 18266688,
#     'id_str': '18266688',
#     'name': 'Tom Fitton',
#     'screen_name': 'TomFitton',
#     'location': 'Washington, DC',
#     'description': 'President, Judicial Watch. (These are my personal views only!)  Author, New York Times best seller Clean House. \nhttps://t.co/midr73gi0A',
#     'url': 'http://t.co/ebnjxMYdbL',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/ebnjxMYdbL',
#         'expanded_url': 'http://www.JudicialWatch.org',
#         'display_url': 'JudicialWatch.org',
#         'indices': [0, 22]}]},
#      'description': {'urls': [{'url': 'https://t.co/midr73gi0A',
#         'expanded_url': 'https://www.instagram.com/tomfitton',
#         'display_url': 'instagram.com/tomfitton',
#         'indices': [113, 136]}]}},
#     'protected': False,
#     'followers_count': 425812,
#     'friends_count': 2907,
#     'listed_count': 1956,
#     'created_at': 'Sat Dec 20 14:32:44 +0000 2008',
#     'favourites_count': 384,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 21989,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '568448',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/964235516794171392/ktAX5u2i_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964235516794171392/ktAX5u2i_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18266688/1527968436',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'ECD295',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4669,
#    'favorite_count': 8501,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 15:47:07 +0000 2018',
#    'id': 1072155760560402433,
#    'id_str': '1072155760560402433',
#    'text': 'RT @joelpollak: This is bad for the FBI and the country. It backs every criticism of \u2066@Comey\u2069 and suspicion the agency tried to protect @Hi…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'joelpollak',
#       'name': 'Joel B. Pollak',
#       'id': 10292132,
#       'id_str': '10292132',
#       'indices': [3, 14]},
#      {'screen_name': 'Comey',
#       'name': 'James Comey',
#       'id': 2334193741,
#       'id_str': '2334193741',
#       'indices': [86, 92]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3407373401,
#     'id_str': '3407373401',
#     'name': 'Terrie Sobeski',
#     'screen_name': 'SobeskiTerrie',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 106,
#     'friends_count': 116,
#     'listed_count': 0,
#     'created_at': 'Fri Aug 07 15:47:46 +0000 2015',
#     'favourites_count': 42459,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 16196,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Dec 10 12:58:07 +0000 2018',
#     'id': 1072113229415931905,
#     'id_str': '1072113229415931905',
#     'text': 'This is bad for the FBI and the country. It backs every criticism of \u2066@Comey\u2069 and suspicion the agency tried to pro… https://t.co/GWNI2RVk2B',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Comey',
#        'name': 'James Comey',
#        'id': 2334193741,
#        'id_str': '2334193741',
#        'indices': [70, 76]}],
#      'urls': [{'url': 'https://t.co/GWNI2RVk2B',
#        'expanded_url': 'https://twitter.com/i/web/status/1072113229415931905',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 10292132,
#      'id_str': '10292132',
#      'name': 'Joel B. Pollak',
#      'screen_name': 'joelpollak',
#      'location': 'Santa Monica, CA',
#      'description': 'Writer, Lawyer, Husband, Dad, NRA member. Host: Breitbart News Tonight, Sirius XM channel 125, 9 p.m. - midnight ET weeknights. Drive safely. 1 Kings 20:11.',
#      'url': 'https://t.co/WRSH4UqxKo',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/WRSH4UqxKo',
#          'expanded_url': 'http://www.breitbart.com/california',
#          'display_url': 'breitbart.com/california',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 72725,
#      'friends_count': 3026,
#      'listed_count': 1398,
#      'created_at': 'Fri Nov 16 02:42:42 +0000 2007',
#      'favourites_count': 1,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 53597,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'E3E319',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1013960382027829248/BZfYqNJw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1013960382027829248/BZfYqNJw_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10292132/1515525004',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '010046',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 824,
#     'favorite_count': 2085,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 824,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 15:47:07 +0000 2018',
#    'id': 1072155760027754496,
#    'id_str': '1072155760027754496',
#    'text': 'RT @AmandiOnAir: What could a grateful nation possibly do to express its eternal thanks to Robert S. Mueller after he brings the treasonous…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AmandiOnAir',
#       'name': 'Fernand R. Amandi',
#       'id': 4900058284,
#       'id_str': '4900058284',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 992172424878804993,
#     'id_str': '992172424878804993',
#     'name': 'lincoln17',
#     'screen_name': 'KathleenLincol9',
#     'location': '',
#     'description': 'Environment is Everything',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 735,
#     'friends_count': 1026,
#     'listed_count': 3,
#     'created_at': 'Thu May 03 22:41:54 +0000 2018',
#     'favourites_count': 19992,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 28259,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1048938464882974720/Hs2dQHQt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1048938464882974720/Hs2dQHQt_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/992172424878804993/1538921393',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Dec 10 12:09:19 +0000 2018',
#     'id': 1072100947789254656,
#     'id_str': '1072100947789254656',
#     'text': 'What could a grateful nation possibly do to express its eternal thanks to Robert S. Mueller after he brings the tre… https://t.co/Yxcmmg8Xw5',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Yxcmmg8Xw5',
#        'expanded_url': 'https://twitter.com/i/web/status/1072100947789254656',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4900058284,
#      'id_str': '4900058284',
#      'name': 'Fernand R. Amandi',
#      'screen_name': 'AmandiOnAir',
#      'location': 'Miami, FL',
#      'description': "6X lottery winner: 1. Fernando & Teresita's son 2. Chenell's spouse 3. Roman & Luna's Daddy 4. Born in 🇺🇸 5. Work B&A 6. Host #StrangeDaysPodcast",
#      'url': 'https://t.co/bI5Zcy5J1r',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/bI5Zcy5J1r',
#          'expanded_url': 'https://www.patreon.com/strangedays',
#          'display_url': 'patreon.com/strangedays',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 44751,
#      'friends_count': 403,
#      'listed_count': 387,
#      'created_at': 'Fri Feb 12 01:56:17 +0000 2016',
#      'favourites_count': 14389,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 20548,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/861440973007671298/u4DxYy-V_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/861440973007671298/u4DxYy-V_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4900058284/1541339780',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '04cb31bae3b3af93',
#      'url': 'https://api.twitter.com/1.1/geo/id/04cb31bae3b3af93.json',
#      'place_type': 'city',
#      'name': 'Miami',
#      'full_name': 'Miami, FL',
#      'country_code': 'US',
#      'country': 'United States',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-80.321683, 25.7090404],
#         [-80.144974, 25.7090404],
#         [-80.144974, 25.855667],
#         [-80.321683, 25.855667]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 234,
#     'favorite_count': 1238,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 234,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 15:47:07 +0000 2018',
#    'id': 1072155759733956608,
#    'id_str': '1072155759733956608',
#    'text': "@realDonaldTrump @FoxNews Damn, you are stupid. You are so painfully stupid it's not even funny anymore. \nPathetic.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [0, 16]},
#      {'screen_name': 'FoxNews',
#       'name': 'Fox News',
#       'id': 1367531,
#       'id_str': '1367531',
#       'indices': [17, 25]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1072095127894667265,
#    'in_reply_to_status_id_str': '1072095127894667265',
#    'in_reply_to_user_id': 25073877,
#    'in_reply_to_user_id_str': '25073877',
#    'in_reply_to_screen_name': 'realDonaldTrump',
#    'user': {'id': 31463572,
#     'id_str': '31463572',
#     'name': 'RamblingMad🌊🌊🌊',
#     'screen_name': 'labecs',
#     'location': 'Bothell, WA',
#     'description': 'Artist, actor, photographer, linguistic supervisor. Proud Decent Human Being! Fighting to get our country back. ♥',
#     'url': 'https://t.co/X2vUZc101o',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/X2vUZc101o',
#         'expanded_url': 'https://www.imdb.com/name/nm1186057/',
#         'display_url': 'imdb.com/name/nm1186057/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1921,
#     'friends_count': 1998,
#     'listed_count': 3,
#     'created_at': 'Wed Apr 15 17:34:49 +0000 2009',
#     'favourites_count': 1524,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9573,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/976966906547650560/wUXHr6Rz_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976966906547650560/wUXHr6Rz_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/31463572/1534266726',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 15:47:07 +0000 2018',
#    'id': 1072155759251722240,
#    'id_str': '1072155759251722240',
#    'text': 'RT @LaurenJauregui: .@realDonaldTrump my dude we all know you’re guilty lol your tweets are just making u look worse (as usual)',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'LaurenJauregui',
#       'name': 'Lauren Jauregui',
#       'id': 363972381,
#       'id_str': '363972381',
#       'indices': [3, 18]},
#      {'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [21, 37]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 64569056,
#     'id_str': '64569056',
#     'name': 'Rob Brooks',
#     'screen_name': 'yesitsbrooksy',
#     'location': 'Swampscott, MA',
#     'description': "I'm not here for a long time, I'm here for a good time\nInstagram/Snapchat: therealbrooksy",
#     'url': 'https://t.co/BpwhyEpyMv',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/BpwhyEpyMv',
#         'expanded_url': 'http://robbrooksphotography.smugmug.com',
#         'display_url': 'robbrooksphotography.smugmug.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1275,
#     'friends_count': 2258,
#     'listed_count': 35,
#     'created_at': 'Tue Aug 11 00:31:52 +0000 2009',
#     'favourites_count': 60761,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 34342,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1020406403905785856/mqLFRstS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1020406403905785856/mqLFRstS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/64569056/1474813937',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Dec 10 15:34:03 +0000 2018',
#     'id': 1072152473224314880,
#     'id_str': '1072152473224314880',
#     'text': '.@realDonaldTrump my dude we all know you’re guilty lol your tweets are just making u look worse (as usual)',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'realDonaldTrump',
#        'name': 'Donald J. Trump',
#        'id': 25073877,
#        'id_str': '25073877',
#        'indices': [1, 17]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 363972381,
#      'id_str': '363972381',
#      'name': 'Lauren Jauregui',
#      'screen_name': 'LaurenJauregui',
#      'location': 'The World ',
#      'description': 'artist. writer. creator. lover. spirit dreamer. magician. entrepreneur. nerd. All I know is that I know nothing at all and am floating on a gas ball in space.',
#      'url': 'https://t.co/YyLwe6uAo1',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/YyLwe6uAo1',
#          'expanded_url': 'https://m.youtube.com/channel/UCztlt79t8cvrtLpnoIXz2Pg',
#          'display_url': 'm.youtube.com/channel/UCztlt…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4089388,
#      'friends_count': 13327,
#      'listed_count': 11757,
#      'created_at': 'Mon Aug 29 00:34:29 +0000 2011',
#      'favourites_count': 10071,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 12667,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1067596625399271424/u_iKBeJV_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1067596625399271424/u_iKBeJV_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/363972381/1543369846',
#      'profile_link_color': 'F5ABB5',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 861,
#     'favorite_count': 4246,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 861,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 15:47:07 +0000 2018',
#    'id': 1072155759117459456,
#    'id_str': '1072155759117459456',
#    'text': "@realDonaldTrump @FoxNews Smocking covfefe? No I think you're smoking crack, or meth.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [0, 16]},
#      {'screen_name': 'FoxNews',
#       'name': 'Fox News',
#       'id': 1367531,
#       'id_str': '1367531',
#       'indices': [17, 25]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1072095127894667265,
#    'in_reply_to_status_id_str': '1072095127894667265',
#    'in_reply_to_user_id': 25073877,
#    'in_reply_to_user_id_str': '25073877',
#    'in_reply_to_screen_name': 'realDonaldTrump',
#    'user': {'id': 1047659675808743425,
#     'id_str': '1047659675808743425',
#     'name': 'Morgan le Fay',
#     'screen_name': 'Morgan_leFay_',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 46,
#     'listed_count': 0,
#     'created_at': 'Thu Oct 04 01:28:26 +0000 2018',
#     'favourites_count': 59,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 18,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1056704423143981057/83boKWZ6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1056704423143981057/83boKWZ6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1047659675808743425/1538619718',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 15:47:07 +0000 2018',
#    'id': 1072155758664536064,
#    'id_str': '1072155758664536064',
#    'text': 'RT @TomFitton: Why is DOJ allowing Mueller special counsel to push political impeachment against @RealDonaldTrump?  Shut it down.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TomFitton',
#       'name': 'Tom Fitton',
#       'id': 18266688,
#       'id_str': '18266688',
#       'indices': [3, 13]},
#      {'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [97, 113]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3097163169,
#     'id_str': '3097163169',
#     'name': 'Simon OG',
#     'screen_name': 'sycomsimon',
#     'location': '',
#     'description': '#WWG1WGA\n#WETHEPEOPLE\nFROM SEA TO SHINING SEA.\nLET FREEDOM RING, PATRIOTS.\nIT IS YOUR TIME.IF AMERICA FALLS,THE WORLD FALLS.\nUNITED WE STAND.GOD BLESS YOU ALL.Q',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 398,
#     'friends_count': 606,
#     'listed_count': 0,
#     'created_at': 'Thu Mar 19 17:08:30 +0000 2015',
#     'favourites_count': 10607,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 10533,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/827257876578131971/fJdYeref_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827257876578131971/fJdYeref_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3097163169/1486068623',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Dec 09 19:43:14 +0000 2018',
#     'id': 1071852790870433792,
#     'id_str': '1071852790870433792',
#     'text': 'Why is DOJ allowing Mueller special counsel to push political impeachment against @RealDonaldTrump?  Shut it down.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'realDonaldTrump',
#        'name': 'Donald J. Trump',
#        'id': 25073877,
#        'id_str': '25073877',
#        'indices': [82, 98]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 18266688,
#      'id_str': '18266688',
#      'name': 'Tom Fitton',
#      'screen_name': 'TomFitton',
#      'location': 'Washington, DC',
#      'description': 'President, Judicial Watch. (These are my personal views only!)  Author, New York Times best seller Clean House. \nhttps://t.co/midr73gi0A',
#      'url': 'http://t.co/ebnjxMYdbL',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/ebnjxMYdbL',
#          'expanded_url': 'http://www.JudicialWatch.org',
#          'display_url': 'JudicialWatch.org',
#          'indices': [0, 22]}]},
#       'description': {'urls': [{'url': 'https://t.co/midr73gi0A',
#          'expanded_url': 'https://www.instagram.com/tomfitton',
#          'display_url': 'instagram.com/tomfitton',
#          'indices': [113, 136]}]}},
#      'protected': False,
#      'followers_count': 425812,
#      'friends_count': 2907,
#      'listed_count': 1956,
#      'created_at': 'Sat Dec 20 14:32:44 +0000 2008',
#      'favourites_count': 384,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 21989,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '568448',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/964235516794171392/ktAX5u2i_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964235516794171392/ktAX5u2i_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18266688/1527968436',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'ECD295',
#      'profile_text_color': '3C3940',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2010,
#     'favorite_count': 4782,
# ...
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/850928694600359936/TT9fwPMA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/850928694600359936/TT9fwPMA_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Dec 10 12:02:24 +0000 2018',
#     'id': 1072099208990212096,
#     'id_str': '1072099208990212096',
#     'text': "The media feeds @realDonaldTrump's lie that his voters never leave. Wrong. Meet Morgan. A working class West Virgin… https://t.co/xhBVYKAxin",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'realDonaldTrump',
#        'name': 'Donald J. Trump',
#        'id': 25073877,
#        'id_str': '25073877',
#        'indices': [16, 32]}],
#      'urls': [{'url': 'https://t.co/xhBVYKAxin',
#        'expanded_url': 'https://twitter.com/i/web/status/1072099208990212096',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2290583342,
#      'id_str': '2290583342',
#      'name': 'Richard N. Ojeda, II',
#      'screen_name': 'VoteOjeda2020',
#      'location': '',
#      'description': 'I spent 24 years fighting for my country only to come home and find out that no one had been fighting for working class families.',
#      'url': 'https://t.co/KjHTd54VZW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KjHTd54VZW',
#          'expanded_url': 'http://www.voteojeda.com/',
#          'display_url': 'voteojeda.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 42115,
#      'friends_count': 3157,
#      'listed_count': 298,
#      'created_at': 'Tue Jan 14 03:42:34 +0000 2014',
#      'favourites_count': 2552,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 5511,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1010342848569532417/j7V4CEsw_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1010342848569532417/j7V4CEsw_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2290583342/1529751466',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 128,
#     'favorite_count': 575,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 128,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Dec 10 15:47:06 +0000 2018',
#    'id': 1072155756429000704,
#    'id_str': '1072155756429000704',
#    'text': 'RT @JimKilbane: @realDonaldTrump https://t.co/RE4S9jb2B8',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JimKilbane',
#       'name': 'I luv being Teamster',
#       'id': 500391228,
#       'id_str': '500391228',
#       'indices': [3, 14]},
#      {'screen_name': 'realDonaldTrump',
#       'name': 'Donald J. Trump',
#       'id': 25073877,
#       'id_str': '25073877',
#       'indices': [16, 32]}],
#     'urls': [],
#     'media': [{'id': 1072153798489960448,
#       'id_str': '1072153798489960448',
#       'indices': [33, 56],
#       'media_url': 'http://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#       'url': 'https://t.co/RE4S9jb2B8',
#       'display_url': 'pic.twitter.com/RE4S9jb2B8',
#       'expanded_url': 'https://twitter.com/JimKilbane/status/1072153806018875392/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'small': {'w': 640, 'h': 480, 'resize': 'fit'}},
#       'source_status_id': 1072153806018875392,
#       'source_status_id_str': '1072153806018875392',
#       'source_user_id': 500391228,
#       'source_user_id_str': '500391228'}]},
#    'extended_entities': {'media': [{'id': 1072153798489960448,
#       'id_str': '1072153798489960448',
#       'indices': [33, 56],
#       'media_url': 'http://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#       'url': 'https://t.co/RE4S9jb2B8',
#       'display_url': 'pic.twitter.com/RE4S9jb2B8',
#       'expanded_url': 'https://twitter.com/JimKilbane/status/1072153806018875392/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 640, 'h': 480, 'resize': 'fit'},
#        'small': {'w': 640, 'h': 480, 'resize': 'fit'}},
#       'source_status_id': 1072153806018875392,
#       'source_status_id_str': '1072153806018875392',
#       'source_user_id': 500391228,
#       'source_user_id_str': '500391228'}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 254303067,
#     'id_str': '254303067',
#     'name': 'MeMyself',
#     'screen_name': 'clakor54',
#     'location': 'Virginia Beach, Virginia',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 524,
#     'friends_count': 1498,
#     'listed_count': 0,
#     'created_at': 'Sat Feb 19 01:28:05 +0000 2011',
#     'favourites_count': 10239,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 12878,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/826516638212186114/oABIyOEu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826516638212186114/oABIyOEu_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/254303067/1485892049',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Dec 10 15:39:21 +0000 2018',
#     'id': 1072153806018875392,
#     'id_str': '1072153806018875392',
#     'text': '@realDonaldTrump https://t.co/RE4S9jb2B8',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'realDonaldTrump',
#        'name': 'Donald J. Trump',
#        'id': 25073877,
#        'id_str': '25073877',
#        'indices': [0, 16]}],
#      'urls': [],
#      'media': [{'id': 1072153798489960448,
#        'id_str': '1072153798489960448',
#        'indices': [17, 40],
#        'media_url': 'http://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#        'url': 'https://t.co/RE4S9jb2B8',
#        'display_url': 'pic.twitter.com/RE4S9jb2B8',
#        'expanded_url': 'https://twitter.com/JimKilbane/status/1072153806018875392/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 640, 'h': 480, 'resize': 'fit'},
#         'small': {'w': 640, 'h': 480, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1072153798489960448,
#        'id_str': '1072153798489960448',
#        'indices': [17, 40],
#        'media_url': 'http://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/DuEOMv-UcAAihNc.jpg',
#        'url': 'https://t.co/RE4S9jb2B8',
#        'display_url': 'pic.twitter.com/RE4S9jb2B8',
#        'expanded_url': 'https://twitter.com/JimKilbane/status/1072153806018875392/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 640, 'h': 480, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 640, 'h': 480, 'resize': 'fit'},
#         'small': {'w': 640, 'h': 480, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1072098604599394305,
#     'in_reply_to_status_id_str': '1072098604599394305',
#     'in_reply_to_user_id': 25073877,
#     'in_reply_to_user_id_str': '25073877',
#     'in_reply_to_screen_name': 'realDonaldTrump',
#     'user': {'id': 500391228,
#      'id_str': '500391228',
#      'name': 'I luv being Teamster',
#      'screen_name': 'JimKilbane',
#      'location': 'Cleveland, OH',
#      'description': 'Elected Trustee/BA #Teamsters local 407, #Unions #1U, father, husband, #Dogs #pitbulls advocate My views not my locals,Non Partisan but the #GOP wants me DEAD..',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 120676,
#      'friends_count': 82183,
#      'listed_count': 517,
#      'created_at': 'Thu Feb 23 02:58:47 +0000 2012',
#      'favourites_count': 46262,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 67289,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/884851220317446145/0Qzjume-_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/884851220317446145/0Qzjume-_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/500391228/1467438393',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 22,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'}],
#  'search_metadata': {'completed_in': 0.074,
#   'max_id': 1072155760560402433,
#   'max_id_str': '1072155760560402433',
#   'next_results': '?max_id=1071799326630862847&q=%40realDonaldTrump&include_entities=1&result_type=mixed',
#   'query': '%40realDonaldTrump',
#   'refresh_url': '?since_id=1072155760560402433&q=%40realDonaldTrump&result_type=mixed&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-dfead4e47f53> in <module>()
#       8                            result_type="recent",
#       9                            include_entities=True,
# ---> 10                            lang="en").items():
#      11     print(tweet)
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     115             # This is a special invocation that returns the underlying
#     116             # APIMethod class
# --> 117             model = ModelParser().parse(self.method(create=True), data)
#     118             if hasattr(self.method, '__self__'):
#     119                 self.method.__self__.parser = old_parser
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/tweepy/parsers.py in parse(self, method, payload)
#     102             result = model.parse_list(method.api, json)
#     103         else:
# --> 104             result = model.parse(method.api, json)
#     105
#     106         if cursors:
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/tweepy/models.py in parse(cls, api, json)
#     278         results.next_results = metadata.get('next_results')
#     279
# --> 280         status_model = getattr(api.parser.model_factory, 'status') if api else Status
#     281
#     282         for status in json['statuses']:
#
# AttributeError: 'JSONParser' object has no attribute 'model_factory'

# %%
public_tweets
# Out:
# {'statuses': [],
#  'search_metadata': {'completed_in': 0.012,
#   'max_id': 1047968027981955072,
#   'max_id_str': '1047968027981955072',
#   'query': '%40james_jiang+Analyze+%40cnn',
#   'refresh_url': '?since_id=1047968027981955072&q=%40james_jiang%20Analyze%20%40cnn&include_entities=1',
#   'count': 2,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
mentions
# Out:
# {'statuses': [{'created_at': 'Sat Sep 29 19:15:58 +0000 2018',
#    'id': 1046116393907892226,
#    'id_str': '1046116393907892226',
#    'text': '@TraderData Analyze: @MowzoonShahin',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TraderData',
#       'name': 'Data Trader',
#       'id': 1021902678123790337,
#       'id_str': '1021902678123790337',
#       'indices': [0, 11]},
#      {'screen_name': 'MowzoonShahin',
#       'name': 'shahin mowzoon',
#       'id': 1039646049688666113,
#       'id_str': '1039646049688666113',
#       'indices': [21, 35]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 1021902678123790337,
#    'in_reply_to_user_id_str': '1021902678123790337',
#    'in_reply_to_screen_name': 'TraderData',
#    'user': {'id': 1039646049688666113,
#     'id_str': '1039646049688666113',
#     'name': 'shahin mowzoon',
#     'screen_name': 'MowzoonShahin',
#     'location': 'AZ',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 1,
#     'listed_count': 0,
#     'created_at': 'Tue Sep 11 22:45:08 +0000 2018',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 261,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sat Sep 29 19:13:10 +0000 2018',
#    'id': 1046115689357090817,
#    'id_str': '1046115689357090817',
#    'text': '@TraderData Analyze:@MowzoonShahin',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TraderData',
#       'name': 'Data Trader',
#       'id': 1021902678123790337,
#       'id_str': '1021902678123790337',
#       'indices': [0, 11]},
#      {'screen_name': 'MowzoonShahin',
#       'name': 'shahin mowzoon',
#       'id': 1039646049688666113,
#       'id_str': '1039646049688666113',
#       'indices': [20, 34]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 1021902678123790337,
#    'in_reply_to_user_id_str': '1021902678123790337',
#    'in_reply_to_screen_name': 'TraderData',
#    'user': {'id': 1039646049688666113,
#     'id_str': '1039646049688666113',
#     'name': 'shahin mowzoon',
#     'screen_name': 'MowzoonShahin',
#     'location': 'AZ',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 0,
#     'friends_count': 1,
#     'listed_count': 0,
#     'created_at': 'Tue Sep 11 22:45:08 +0000 2018',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 261,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.034,
#   'max_id': 1046116393907892226,
#   'max_id_str': '1046116393907892226',
#   'query': '%40TraderData+Analyze%3A',
#   'refresh_url': '?since_id=1046116393907892226&q=%40TraderData%20Analyze%3A&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}
